# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as scs
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, confusion_matrix
import re

np.random.seed(42)

# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('2016-first-quarter-hate-crime-data.csv')

# %%
df
# Out:
#   Case Number   Date and Time Day of Week  Total\nNumber of\nVictims  \
# 0   B16-04899  02/06/16 22:50    Saturday                        1.0
# 1   B16-05230  02/06/16 02:30    Saturday                        1.0
# 2   B16-09812  03/14/16 18:23      Monday                        1.0
# 3         NaN             NaN         NaN                        NaN
# 4         NaN             NaN         NaN                        NaN
# 5         NaN             NaN         NaN                        NaN
# 6         NaN             NaN         NaN                        NaN
# 7         NaN             NaN         NaN                        NaN
#
#   Victim Race Victim Sex \nVictim Type  Total\nNumber of\nOffenders  \
# 0           W       Male    Individual                          2.0
# 1           B       Male    Individual                          3.0
# 2           W       Male    Individual                          1.0
# 3         NaN        NaN           NaN                          NaN
# 4         NaN        NaN           NaN                          NaN
# 5         NaN        NaN           NaN                          NaN
# 6         NaN        NaN           NaN                          NaN
# 7         NaN        NaN           NaN                          NaN
#
#   Offender\nRace Offender Sex      Offense/ Crime  \
# 0              W            M      Simple Assault
# 1              W            M      Simple Assault
# 2              W            M  Aggravated Battery
# 3            NaN          NaN                 NaN
# 4            NaN          NaN                 NaN
# 5            NaN          NaN                 NaN
# 6            NaN          NaN                 NaN
# 7            NaN          NaN                 NaN
#
#   Offense/ Crime\nLocation Type Offense/Crime \nBias\nMotivation
# 0                    Restaurant             Anti-Homosexual Male
# 1                       Highway                       Anti-Black
# 2                       Highway                        Anti-Arab
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# 5                           NaN                              NaN
# 6                           NaN                              NaN
# 7                           NaN                              NaN
